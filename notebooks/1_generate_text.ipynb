# %%
# %load_ext autoreload
# %autoreload 2

# %%
import setup_path

# %% [markdown]
# ## Generate with Gemini

# %%
from genai_clients.text.gemini import generate_text as generate_text_gemini

# %%
system_prompt = "You are a helpful assistant."
user_prompt = "What is the capital of France?"

output = generate_text_gemini(system_prompt, user_prompt)

print(output)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## Generate with GPT

# %%
from genai_clients.text.gpt import generate_text as generate_text_gpt

# %%
system_prompt = "You are a helpful assistant."
user_prompt = "What is the capital of France?"

output = generate_text_gpt(system_prompt, user_prompt)

print(output)
# Out:
# The capital of France is Paris.
