# %%
# %load_ext autoreload
# %autoreload 2

# %%
import setup_path

# %% [markdown]
# ## Creating a collection

# %%
from dbs.vectordb.qdrant_client import create_collection
create_collection("my_collection")
# Out:
# 'Collection already exists'

# %%
## Add documents
from dbs.vectordb.qdrant_client import add_document

# %%
docs = [
    "France is a country in Western Europe.",
    "Germany is a country in Central Europe.",
    "Italy is a country in Southern Europe.",
]

for doc in docs:
    add_document("my_collection", doc)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 8
#       1 docs = [
#       2     "France is a country in Western Europe.",
#       3     "Germany is a country in Central Europe.",
#       4     "Italy is a country in Southern Europe.",
#       5 ]
#       7 for doc in docs:
# ----> 8     add_document("my_collection", doc)
#
# File ~/hands-on-genai/dbs/vectordb/qdrant_client.py:31, in add_document(collection_name, document, id)
#      29 if id is None:
#      30     id = str(uuid.uuid4())
# ---> 31 client.add(
#      32     collection_name=collection_name,
#      33     documents=[models.Document(text=document, model=model_name)],
#      34     ids=[id],
#      35 )
#      36 return "Document added successfully"
#
# ...

# %%
## Search documents
from dbs.vectordb.qdrant_client import search_documents
